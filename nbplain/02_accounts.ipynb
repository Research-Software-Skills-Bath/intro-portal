# %% [markdown]
# # Accounts

# %% [markdown]
# ## Overview:
#
# - **Teaching:** 5 min
# - **Exercises:** 0 min
#
# **Questions**
# - Where can I see the accounts I have access to?
# - How do I set up an account?

# %% [markdown]
# ## Where can I see the accounts I have access to?
#
# You can navigate to the accounts screen to see what accounts you have on the system from the portal home page:
#
#
# ![Portal Account](../images/ResearchFinancePortalAccount.png)
#
#
#
# or from the sidebar `Accounts` menu:
#
# ![Account side bar](../images/AccountSidebar.png)

# %% [markdown]
# Once you’ve selected Accounts you will see a list of accounts you have access to and against each account listed a set of options for Managing/ Viewing account, allocating budgets, and viewing finance will be available.

# %% [markdown]
# ## Exercise: Logging in
#
# Open a web browser and navigate to [https://rcam.bath.ac.uk](https://rcam.bath.ac.uk) and log in with your University credentials.

# %% [markdown]
# ## Key Points:
#
# - The Research Computing Finance Portal can be accessed at:  [https://rcam.bath.ac.uk](https://rcam.bath.ac.uk)
# - In the portal you can manage Research Computing resources, and monitor usage and budgets.
