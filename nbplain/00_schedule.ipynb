# %% [markdown]
# # Introducing the Portal

# %% [markdown]
# The following workshop is an introduction to the Research computing finance portal, which you can use to manage your computing resources at the University of Bath. In order to carry out this workshop you will need an active Agresso account code with which you can set up resources allocations.

# %% [markdown]
# ## Schedule
#
# Approximate timings for the workshop:
#
# | Time | Episode | Description |
# |---|---|---|
# | -:-- | [Introducing the Portal](./01_Introduction.ipynb) | Introduction to the Research Computing Finance Portal |
# | -:-- | [Accounts](./02_accounts.ipynb) | Overview of Accounts |
# | -:-- | [Resource Allocations](./03_resourceallocations.ipynb) | Overview of Resource Allocations |
# | -:-- | [Managing Budgets](./04_budgets.ipynb) | How to manage budgets |
